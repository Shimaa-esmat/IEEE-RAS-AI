# %% [markdown]
# ### Preparatory Step

# %%
# Prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# ### About the Dataset
# We'll continue working with the Pokémon dataset in this workspace. The data was assembled from the database of information found in this [GitHub repository](https://github.com/veekun/pokedex/tree/master/pokedex/data/csv).

# %%
pokemon = pd.read_csv('pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1
# 0   1   bulbasaur              1     0.7     6.9               64  grass  \
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# ### **TO DO Task**
# Pokémon have a number of different statistics that describe their combat capabilities. Here, create a _histogram_ that depicts the distribution of 'special-defense' values taken.
#
# **Hint**: Try playing around with different bin width sizes to see what best depicts the data.

# %%
# Try playing around with different bin width sizes
bins = np.arange(0, pokemon['special-defense'].max()+5, 5)
sb.distplot(pokemon['special-defense'], bins = bins , kde = True);
# Out:
# C:\Users\shyma\AppData\Local\Temp\ipykernel_21984\913049281.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(pokemon['special-defense'], bins = bins , kde = True);

# %%
bins = np.arange(0, pokemon['special-defense'].max()+10, 10)
sb.distplot(pokemon['special-defense'], bins = bins , kde = True)
# Out:
# C:\Users\shyma\AppData\Local\Temp\ipykernel_21984\1894177688.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(pokemon['special-defense'], bins = bins , kde = True)
# <Axes: xlabel='special-defense', ylabel='Density'>

# %%
bins = np.arange(0, pokemon['special-defense'].max()+50, 50)
sb.displot(data=pokemon,x='special-defense', bins = bins , kde = True)
