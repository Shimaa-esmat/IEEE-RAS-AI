# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# Once again, we make use of the Pokémon data for this exercise.

# %%
pokemon = pd.read_csv('pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1
# 0   1   bulbasaur              1     0.7     6.9               64  grass  \
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# ## TO DO **Task 1**
# There are also variables in the dataset that don't have anything to do with the game mechanics, and are just there for flavor. Try plotting the distribution of Pokémon heights (given in meters). For this exercise, experiment with different axis limits as well as bin widths to see what gives the clearest view of the data.

# %%
plt.figure(figsize = [20, 5])
# HISTOGRAM ON LEFT: full data without scaling
plt.subplot(1, 3, 1)
plt.hist(data=pokemon, x='height');
plt.xlabel('Initial plot with original data')
# HISTOGRAM ON center : They are only scaled to log-type
plt.subplot(1, 3, 2)
bins = np.arange(0, pokemon['height'].max()+5, 5)
plt.hist(data=pokemon, x='height', bins=bins);
plt.xscale('log')
plt.xlabel('The x-axis limits NOT are changed. They are only scaled to log-type')
# HISTOGRAM ON left : Wider bins and narrow axis limits:
plt.subplot(1, 3, 3)
plt.hist(pokemon['height'], bins=100, range=(0,15));
plt.xlabel('The x-axis limits NOT are changed. They are Wider bins and narrow axis limits')
# Out:
# Text(0.5, 0, 'The x-axis limits NOT are changed. They are Wider bins and narrow axis limits')

# %%
pokemon['height'].describe()
# Out:
# count    807.000000
# mean       1.162454
# std        1.081030
# min        0.100000
# 25%        0.600000
# 50%        1.000000
# 75%        1.500000
# max       14.500000
# Name: height, dtype: float64

# %%
# change the axis limit
bins = 10 ** np.arange(-1, 2+0.1, 0.1)
plt.hist(data=pokemon, x='height', bins=bins);

plt.xscale('log')
plt.xlabel('x-axis limits are changed, and scaled to log-type');

# %%
np.log10(pokemon['height'].describe())
# Out:
# count    2.906874
# mean     0.065376
# std      0.033838
# min     -1.000000
# 25%     -0.221849
# 50%      0.000000
# 75%      0.176091
# max      1.161368
# Name: height, dtype: float64

# %% [markdown]
# ## TO DO **Task 2**
# In this task, you should plot the distribution of Pokémon weights (given in kilograms). Due to the very large range of values taken, you will probably want to perform an _axis transformation_ as part of your visualization workflow.

# %%
plt.figure(figsize = [20, 5])
# HISTOGRAM ON LEFT: full data without scaling
plt.subplot(1, 3, 1)
plt.hist(data=pokemon, x='weight');
plt.xlabel('Initial plot with original data')
plt.subplot(1, 3, 2)
bins = np.arange(0, pokemon['weight'].max()+5, 5)
plt.hist(data=pokemon, x='weight', bins=bins);
plt.xscale('log')
plt.xlabel('The x-axis limits NOT are changed. They are only scaled to log-type');
# HISTOGRAM ON left : Wider bins and narrow axis limits:
plt.subplot(1, 3, 3)
plt.hist(pokemon['weight'], bins=1000, range=(0,1000));
plt.xlabel('The x-axis limits NOT are changed. They are only Wider bins and narrow axis limits');

# %%
# # change the axis limit
bins = 10 ** np.arange(-1, 3+0.1, 0.1)
plt.hist(data=pokemon, x='weight', bins=bins);

plt.xscale('log')
plt.xlabel('x-axis limits are changed, and scaled to log-type');
