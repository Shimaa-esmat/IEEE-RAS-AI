# %% [markdown]
# # Task 15 - Exploring with visuals and conclusions - due 23 August 2022

# %% [markdown]
# # Exploring with Visuals
# Use `clean_08.csv` and `clean_18.csv` to answer the questions in each cell

# %%
# load datasets
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df08 = pd.read_csv('clean_08.csv')
df18 = pd.read_csv('clean_18.csv')

# %%
df08.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV  \
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score
# 0                  7.0      15.0     20.0     17.0                     4  \
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
df18.head(16)
# Out:
#                    model  displ  cyl       trans drive      fuel    veh_class
# 0              ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline    small SUV  \
# 1              ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline    small SUV
# 2              ACURA TLX    2.4    4       AMS-8   2WD  Gasoline    small car
# 3              ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline    small car
# 4              ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline    small car
# 5   ACURA TLX AWD A-SPEC    3.5    6  SemiAuto-9   4WD  Gasoline    small car
# 6   ACURA TLX FWD A-SPEC    3.5    6  SemiAuto-9   2WD  Gasoline    small car
# 7          ALFA ROMEO 4C    1.8    4   AutoMan-6   2WD  Gasoline    small car
# 8      ALFA ROMEO Giulia    2.9    6      Auto-8   2WD  Gasoline  midsize car
# 9                AUDI A3    2.0    4       AMS-6   4WD  Gasoline    small car
# 10               AUDI A3    2.0    4       AMS-7   2WD  Gasoline    small car
# ...

# %%
df = df18[df18['smartway'] == 'Yes']
df
# Out:
#                               model  displ  cyl       trans drive
# 15                    AUDI A4 Ultra    2.0    4       AMS-7   2WD  \
# 120                    BUICK Encore    1.4    4  SemiAuto-6   2WD
# 168                 CHEVROLET Cruze    1.4    4       Man-6   2WD
# 169                 CHEVROLET Cruze    1.4    4  SemiAuto-6   2WD
# 170                 CHEVROLET Cruze    1.6    4      Auto-9   2WD
# ..                              ...    ...  ...         ...   ...
# 788  MINI Cooper SE Countryman All4    1.5    3  SemiAuto-6   4WD
# 794                        BMW 330e    2.0    4  SemiAuto-8   2WD
# 797                        BMW 740e    2.0    4  SemiAuto-8   4WD
# 806                  CHEVROLET Volt    1.5    4         CVT   2WD
# 826  MINI Cooper SE Countryman All4    1.5    3  SemiAuto-6   4WD
#
#             fuel    veh_class  air_pollution_score  city_mpg  hwy_mpg
# 15      Gasoline    small car                  3.0      27.0     37.0  \
# ...

# %%
# Compare the distributions of greenhouse gas score in 2008 and 2018: ______
# normal for both - both are skewed to the right - 2008 is more skewed to the left - 2018 is more skewed to the left
# Can you plot both in a single plot?
pd.concat([df08.greenhouse_gas_score.describe(), df18.greenhouse_gas_score.describe()], axis=1)
# Out:
#        greenhouse_gas_score  greenhouse_gas_score
# count            987.000000            832.000000
# mean               5.196555              4.750000
# std                1.909692              1.750365
# min                0.000000              1.000000
# 25%                4.000000              3.000000
# 50%                6.000000              5.000000
# 75%                6.000000              6.000000
# max               10.000000             10.000000

# %%
df18.greenhouse_gas_score.plot.kde(alpha=0.5, label='Column 1')
df08.greenhouse_gas_score.plot.kde(alpha=0.5, label='Column 2')
plt.legend(loc='upper right')
plt.show()

# %%
df18.greenhouse_gas_score.hist(figsize=(5,5));
df08.greenhouse_gas_score.hist(figsize=(5,5));

# %%
# How has the distribution of combined mpg changed from 2008 to 2018?_______
pd.concat([df08.cmb_mpg.describe(), df18.cmb_mpg.describe()], axis=1)
# Stayed the same - became skewed in the opposite direction - Became much more skewed to the right - Moved closer to normal distribution
# You can plot the kde (look it up) to be sure of your answer
df18.cmb_mpg.plot.kde(alpha=0.5, label='Column 1')
df08.cmb_mpg.plot.kde(alpha=0.5, label='Column 2')
plt.legend(loc='upper right')
plt.show()

# %%
df18.cmb_mpg.hist(figsize=(5,5));
df08.cmb_mpg.hist(figsize=(5,5));

# %%
# Choose the correlation between engine displacement and combined mpg? __________
df08.displ.corr(df08.cmb_mpg)
df08.plot(x='displ', y='cmb_mpg', kind='scatter');
# Positive correlation - Negative - None

# %%
df18.displ.corr(df18.cmb_mpg)
df18.plot(x='displ', y='cmb_mpg', kind='scatter');

# %%
# Choose the correlation between greenhouse gas score and combined mpg? __________
df08.greenhouse_gas_score.corr(df08.cmb_mpg)
df08.plot(x='displ', y='greenhouse_gas_score', kind='scatter');

# Positive correlation -- Negative - None

# %%
df18.greenhouse_gas_score.corr(df18.cmb_mpg)
df18.plot(x='displ', y='greenhouse_gas_score', kind='scatter');

# %% [markdown]
# # Drawing Conclusions

# %% [markdown]
# ### Q1: How much have vehicle classes improved in fuel economy in 2018 compared to 2008?

# %%
# use plots if you can
veh08 = df08.groupby(['veh_class']).cmb_mpg.mean()
veh18 = df18.groupby('veh_class').cmb_mpg.mean()
veh18
# Out:
# veh_class
# large car          23.409091
# midsize car        27.884058
# minivan            20.800000
# pickup             18.589744
# small SUV          24.074074
# small car          25.421053
# special purpose    18.500000
# standard SUV       18.197674
# station wagon      27.529412
# Name: cmb_mpg, dtype: float64

# %%
x = veh18 - veh08
x
# Out:
# veh_class
# SUV                     NaN
# large car          4.900000
# midsize car        6.282609
# minivan            1.682353
# pickup             2.312635
# small SUV               NaN
# small car          4.315948
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.162745
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
x.dropna(inplace=True)
x
plt.subplots(figsize=(8, 5))
plt.bar(x.index, x)
plt.xlabel('Vehicle Class')
plt.ylabel('Combined MPG');

# %%
df18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV  \
# 1  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 2  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 4  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score
# 0                  3.0      20.0     28.0     23.0                     5  \
# 1                  3.0      19.0     27.0     22.0                     4
# 2                  3.0      23.0     33.0     27.0                     6
# 3                  3.0      20.0     32.0     24.0                     5
# 4                  3.0      21.0     30.0     24.0                     5
#
#   smartway
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
smartway18 = df18[df18['smartway'] == 'Yes']
smartway18
# Out:
#                               model  displ  cyl       trans drive
# 15                    AUDI A4 Ultra    2.0    4       AMS-7   2WD  \
# 120                    BUICK Encore    1.4    4  SemiAuto-6   2WD
# 168                 CHEVROLET Cruze    1.4    4       Man-6   2WD
# 169                 CHEVROLET Cruze    1.4    4  SemiAuto-6   2WD
# 170                 CHEVROLET Cruze    1.6    4      Auto-9   2WD
# ..                              ...    ...  ...         ...   ...
# 788  MINI Cooper SE Countryman All4    1.5    3  SemiAuto-6   4WD
# 794                        BMW 330e    2.0    4  SemiAuto-8   2WD
# 797                        BMW 740e    2.0    4  SemiAuto-8   4WD
# 806                  CHEVROLET Volt    1.5    4         CVT   2WD
# 826  MINI Cooper SE Countryman All4    1.5    3  SemiAuto-6   4WD
#
#             fuel    veh_class  air_pollution_score  city_mpg  hwy_mpg
# 15      Gasoline    small car                  3.0      27.0     37.0  \
# ...

# %% [markdown]
# ### Q2: What are the characteristics of SmartWay vehicles? Have they changed over time?
# Compare the following features --> drive, cyl, fuel in both datasets. Write your comments and findings in each cell
# Use plots

# %%
# compare drive
smartway08 = df08[df08['smartway'] == 'yes']
smartway18 = df18[df18['smartway'] == 'Yes']
drive08 = smartway08["drive"].value_counts()
drive18 = smartway18["drive"].value_counts()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.bar(drive08.index, drive08.values)
ax1.set_title("2008")
ax2.bar(drive18.index, drive18.values)
ax2.set_title("2018")
# plt.bar(drive08.index , drive08)
# plt.bar(drive18.index , drive18)
# Out:
# Text(0.5, 1.0, '2018')

# %%
smartway18.head()
# Out:
#                model  displ  cyl       trans drive      fuel  veh_class
# 15     AUDI A4 Ultra    2.0    4       AMS-7   2WD  Gasoline  small car  \
# 120     BUICK Encore    1.4    4  SemiAuto-6   2WD  Gasoline  small SUV
# 168  CHEVROLET Cruze    1.4    4       Man-6   2WD  Gasoline  small car
# 169  CHEVROLET Cruze    1.4    4  SemiAuto-6   2WD  Gasoline  small car
# 170  CHEVROLET Cruze    1.6    4      Auto-9   2WD    Diesel  small car
#
#      air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score
# 15                   3.0      27.0     37.0     31.0                     7  \
# 120                  3.0      27.0     33.0     30.0                     7
# 168                  6.0      27.0     40.0     32.0                     7
# 169                  6.0      29.0     40.0     33.0                     8
# 170                  3.0      31.0     47.0     37.0                     7
#
#     smartway
# 15       Yes
# 120      Yes
# 168      Yes
# 169      Yes
# ...

# %%
# compare the number of cylinders
cyl08 = smartway08["cyl"].value_counts()
cyl18 = smartway18["cyl"].value_counts()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.pie(cyl08, labels=cyl08.index, autopct='%1.1f%%')
ax1.set_title("2008")

ax2.pie(cyl18, labels=cyl18.index, autopct='%1.1f%%')
ax2.set_title("2018")

plt.show()
# Can you use a pie chart with the percentages shown?

# %%
# compare the fuel used
fuel08 = smartway08["fuel"].value_counts()
fuel18 = smartway18["fuel"].value_counts()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.pie(fuel08, labels=fuel08.index, autopct='%1.1f%%')
ax1.set_title("2008")

ax2.pie(fuel18, labels=fuel18.index, autopct='%1.1f%%')
ax2.set_title("2018")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.bar(fuel08.index, fuel08.values)
ax1.set_title("2008")
ax2.bar(fuel18.index, fuel18.values)
ax2.set_title("2018")

plt.show()

# %% [markdown]
# ### Q3: What features (variables) are associated with better fuel economy (positive corr)? ـــــــــــ

# %%
# use plots
cmb08 = df08.query('cmb_mpg > cmb_mpg.mean()')
cmb08 = cmb08.describe()
cmb18 = df18.query('cmb_mpg > cmb_mpg.mean()')
cmb18 = cmb18.describe()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.bar(cmb08.index, cmb08['cmb_mpg'])
ax1.set_title("2008")
ax2.bar(cmb18.index, cmb18['cmb_mpg'])
ax2.set_title("2018")
# Out:
# Text(0.5, 1.0, '2018')

# %% [markdown]
# ### Q4: What is the most efficient vehicle class in fuel consumption? ـــــــــــــــــــ

# %%
# use plots

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

df08.groupby("veh_class")["cmb_mpg"].mean().plot(kind="bar", ax=axs[0])
axs[0].set_title("2008")
df18.groupby("veh_class")["cmb_mpg"].mean().plot(kind="bar", ax=axs[1])
axs[1].set_title("2018")
plt.show()

# %% [markdown]
# ### Q5: Are smartway vehicles associated with better fuel economy? ـــــــــــــــــــ

# %%
# use plots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

df08.groupby("smartway")["cmb_mpg"].mean().plot(kind="bar", ax=axs[0])
axs[0].set_title("2008")
df18.groupby("smartway")["cmb_mpg"].mean().plot(kind="bar", ax=axs[1])
axs[1].set_title("2018")

plt.show()

# %% [markdown]
# ### Q6: For all of the models that were produced in 2008 that are still being produced in 2018, how much has the mpg improved and which vehicle improved the most?
# This is a question regarding models that were updated since 2008 and still being produced in 2018. In order to do this, we need a way to compare models that exist in both datasets. You need to learn how to [merge](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) dataframes

# %% [markdown]
# ![inner-outer.png](attachment:inner-outer.png)

# %% [markdown]
# ![left-right.png](attachment:left-right.png)

# %% [markdown]
# ## Merging Datasets
# Rename 2008 columns to distinguish from 2018 columns after the merge.
# To do this, take the first 10 characters of the column label and and concatenate it with _2008. (Only take the first 10 characters to prevent really long column names.)

# %%
# rename 2008 columns only
df08.rename(columns=lambda x: x[:10] + "_2008",inplace=True)

# %%
# merge datasets
df=df08.merge(df18, left_on='model_2008', right_on='model', how='inner')

# %%
# view to check merge
df.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline  \
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008  ...
# 0            SUV              7.0           17.0          22.0  ...  \
# 1            SUV              7.0           17.0          22.0  ...
# 2  station wagon              7.0           21.0          29.0  ...
# 3  station wagon              7.0           21.0          29.0  ...
# 4  station wagon              7.0           22.0          29.0  ...
#
#         trans  drive      fuel  veh_class  air_pollution_score  city_mpg
# 0  SemiAuto-6    2WD  Gasoline  small SUV                  3.0      20.0  \
# ...

# %%
# How many columns are there after the merge?____ reach me if this number is not 26
df.shape[1]
# Out:
# 26

# %%
# save the combined dataset as 'combined_dataset.csv'
df.to_csv('combined_dataset.csv', index=False)

# %% [markdown]
# # Results with Merged Dataset

# %% [markdown]
# ### 1. Create a new dataframe, `model_mpg`, that contain the mean combined mpg values in 2008 and 2018 for each unique model
#
# To do this, group by `model` and find the mean `cmb_mpg_2008` and mean `cmb_mpg` for each.

# %%
combined = pd.concat([df08, df18], axis=1, join='inner')
model_mpg = combined.groupby('model')[['cmb_mpg_2008','cmb_mpg']].mean()

# %%
model_mpg.head()
# Out:
#                       cmb_mpg_2008  cmb_mpg
# model
# ACURA RDX                     18.0     22.5
# ACURA TLX                     20.0     25.0
# ACURA TLX AWD A-SPEC          21.0     23.0
# ACURA TLX FWD A-SPEC          22.0     23.0
# ALFA ROMEO 4C                 23.0     28.0

# %% [markdown]
# ### 2. Create a new column, `mpg_change`, with the change in mean mpg

# %%
model_mpg['mpg_change'] = model_mpg['cmb_mpg'] - model_mpg['cmb_mpg_2008']
model_mpg.head()
# Out:
#                       cmb_mpg_2008  cmb_mpg  mpg_change
# model
# ACURA RDX                     18.0     22.5         4.5
# ACURA TLX                     20.0     25.0         5.0
# ACURA TLX AWD A-SPEC          21.0     23.0         2.0
# ACURA TLX FWD A-SPEC          22.0     23.0         1.0
# ALFA ROMEO 4C                 23.0     28.0         5.0

# %% [markdown]
# ### 3. Find the vehicle that improved the most
# Can you do this using a single method ?

# %%
 model_mpg['mpg_change'].max()
# Out:
# 54.0

# %%
model_mpg[model_mpg['mpg_change'] == 54.0]
# Out:
#                 cmb_mpg_2008  cmb_mpg  mpg_change
# model
# CHEVROLET Volt          20.0     74.0        54.0

# %%
df18
# Out:
#                   model  displ  cyl       trans drive         fuel
# 0             ACURA RDX    3.5    6  SemiAuto-6   2WD     Gasoline  \
# 1             ACURA RDX    3.5    6  SemiAuto-6   4WD     Gasoline
# 2             ACURA TLX    2.4    4       AMS-8   2WD     Gasoline
# 3             ACURA TLX    3.5    6  SemiAuto-9   2WD     Gasoline
# 4             ACURA TLX    3.5    6  SemiAuto-9   4WD     Gasoline
# ..                  ...    ...  ...         ...   ...          ...
# 827  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD          Gas
# 828   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD          Gas
# 829           VOLVO S90    2.0    4  SemiAuto-8   4WD  Electricity
# 830         VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Electricity
# 831         VOLVO XC 90    2.0    4  SemiAuto-8   4WD  Electricity
#
#         veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg
# 0       small SUV                  3.0      20.0     28.0     23.0  \
# ...

# %% [markdown]
# # Your AI head can't tell what car to buy!!
# Omar lives in a city and wants to buy a car. He likes it to be mid size with 6 gears manual transimission. He also cares about fuel consumption.
# Suggest two cars: one that is two wheel drive and the other is four wheel drive (use the 2018 dataset)
# It better not be expensive :)

# %%
midsize_cars = df18[(df18["veh_class"] == "midsize car") & (df18["cyl"] == 6)]

wd2 = midsize_cars[midsize_cars["drive"] == "2WD"]
wd4 = midsize_cars[midsize_cars["drive"] == "4WD"]
wd2 = wd2.sort_values("cmb_mpg", ascending=False)
wd4 = wd4.sort_values("cmb_mpg", ascending=False)
wd21 = wd2.iloc[0]["model"]
wd41 = wd4.iloc[0]["model"]

# Print the recommended models
print("two wheel drive: ", wd21)
print("four wheel drive: ", wd41)
# Out:
# two wheel drive:  INFINITI Q70 Hybrid
# four wheel drive:  AUDI S5 Sportback

# %% [markdown]
# # What are your findings ?
# ### Write a detailed paragraph to describe your findings.
# This is a very important question, if you do not answer this in detail, this task is considered not submitted and will not be graded

# %%
# From analysis of datasets from 2008 and 2018
# 2008 distribution is skewed to the left. The mean is dragged down and is smaller than the median.
# This could be due to several outliers with smaller greenhouse gas score values.
# vehicles with higher air pollution scores, higher greenhouse gas scoresand higher city and highway mpg have better fuel economy.
# There is a negative correlation.The higher the engine displacement, the lower the combined city/highway fuel economy .
# There is a positive correlation. The higher the greenhouse gas score rating, the higher the combined city/highway fuel economy .
# the alternative sources of fuel available in 2008 are CNG and ethanol, and those in 2018 ethanol and electricity
# Since 2018, the number of models using alternative sources have increased 
# Midsize car, station wagon and large car have the highest improvements in fuel economy then small car, pickup and mini van.
# SmartWay are vehicles that received a combined score of greenhouse gas and air pollution higher than the average rating.
# SmartWay vehicles are associated with better fuel economy than non-SmartWay vehicles in both 2008 and 2018. 
# City and highway MPG or the combined feature, combined MPG is associated with better fuel economy.
# SmartWay vehicle can be an effective way to improve fuel economy and reduce environmental impact.\
# he actual prices may vary depending on the location and specific options,
